# %% [markdown]
# **Лабораторный практикум по курсу «Распознавание диктора», Университет ИТМО, 2021**

# %% [markdown]
# **Лабораторная работа №3. Построение дикторских моделей и их сравнение**
#
# **Цель работы:** изучение процедуры построения дикторских моделей с использованием глубоких нейросетевых архитектур.
#
# **Краткое описание:** в рамках настоящей лабораторной работы предлагается изучить и реализовать схему построения дикторских моделей с использованием глубокой нейросетевой архитектуры, построенной на основе ResNet-блоков. Процедуры обучения и тестирования предлагается рассмотреть по отношению к задаче идентификации на закрытом множестве, то есть для ситуации, когда дикторские классы являются строго заданными. Тестирование полученной системы предполагает использование доли правильных ответов (accuracy) в качестве целевой метрики оценки качества.
#
# **Данные:** в качестве данных для выполнения лабораторной работы предлагается использовать базу [VoxCeleb1](http://www.robots.ox.ac.uk/~vgg/data/voxceleb/vox1.html).
#
# **Содержание лабораторной работы**
#
# 1. Подготовка данных для обучения и тестирования блока построения дикторских моделей.
#
# 2. Обучение параметров блока построения дикторских моделей без учёта процедуры аугментации данных.
#
# 3. Обучение параметров блока построения дикторских моделей с учётом процедуры аугментации данных.
#
# 4. Тестированное блока построения дикторских моделей.

# %%
# IPython extension to reload modules before executing user code
# %load_ext autoreload
# %autoreload 2

# Import of modules
import os
import sys

sys.path.append(os.path.realpath('..'))

import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from common import download_dataset, concatenate, extract_dataset, part_extract, download_protocol, split_musan
from exercises_blank import train_dataset_loader, test_dataset_loader, ResNet, MainModel, train_network, test_network
from ResNetBlocks import BasicBlock
from LossFunction import AAMSoftmaxLoss
from Optimizer import SGDOptimizer
from Scheduler import OneCycleLRScheduler
from load_save_pth import saveParameters, loadParameters

# %% [markdown]
# **1. Подготовка данных для обучения и тестирования детектора речевой активности**
#
# В ходе выполнения лабораторной работы необходимы данные для выполнения процедуры обучения и процедуры тестирования нейросетевого блока генерации дикторских моделей. Возьмём в качестве этих данных звукозаписи, сохраненные в формат *wav*, из корпуса [VoxCeleb1 dev set](https://www.robots.ox.ac.uk/~vgg/data/voxceleb/vox1.html). Данный корпус содержит 148,642 звукозаписи (частота дискретизации равна 16кГц) для 1,211 дикторов женского и мужского пола, разговаривающих преимущественно на английском языке.
#
# В рамках настоящего пункта требуется выполнить загрузку и распаковку звуковых wav-файлов из корпуса VoxCeleb1 dev set.
#
# ![Рисунок 1](https://analyticsindiamag.com/wp-content/uploads/2020/12/image.png "VoxCeleb. Крупномасштабная аудиовизуальная база данных человеческой речи.")

# %%
# Download VoxCeleb1 (test set)
with open('../data/lists/datasets.txt', 'r') as f:
    lines = f.readlines()

download_dataset(lines, user='voxceleb1902', password='nx0bl2v2', save_path='../data')

# %%
# Concatenate archives for VoxCeleb1 dev set
with open('../data/lists/concat_arch.txt', 'r') as f:
    lines = f.readlines()
    
concatenate(lines, save_path='../data')

# %%
# Extract VoxCeleb1 dev set
extract_dataset(save_path='../data/voxceleb1_dev', fname='../data/vox1_dev_wav.zip')

# %%
# Download VoxCeleb1 identification protocol
with open('../data/lists/protocols.txt', 'r') as f:
    lines = f.readlines()
    
download_protocol(lines, save_path='../data/voxceleb1_test')

# %% [markdown]
# **2. Обучение параметров блока построения дикторских моделей без учёта процедуры аугментации данных**
#
# Построение современных дикторских моделей, как правило, выполняется с использованием нейросетевых архитектур, многие из которых позаимствованы из области обработки цифровых изображений. Одними из наиболее распространенных нейросетевых архитектур, используемыми для построения дикторских моделей, являются [ResNet-подобные архитектуры](https://arxiv.org/pdf/1512.03385.pdf). В рамках настоящего пункта предлагается выполнить адаптацию нейросетевой архитектуры ResNet34 для решения задачи генерации дикторских моделей (дикторских эмбеддингов). *Дикторский эмбеддинг* – это высокоуровневый вектор-признаков, состоящий, например, из 128, 256 и т.п. значений, содержащий особенности голоса конкретного человека. При решении задачи распознавания диктора можно выделить эталонные и тестовые дикторские эмбеддинги. *Эталонные эмбеддинги* формируются на этапе регистрации дикторской модели определённого человека и находятся в некотором хранилище данных. *Тестовые эмбеддинги* формируются на этапе непосредственного использования системы голосовой биометрии на практике, когда некоторый пользователь пытается получить доступ к соответствующим ресурсам. Система голосовой биометрии сравнивает по определённой метрике эталонные и тестовые эмбеддинги, формируя оценку сравнения, которая, после её обработки блоком принятия решения, позволяет сделать вывод о том, эмбеддинги одинаковых или разных дикторов сравниваются между собой.
#
# Адаптация различных нейросетевых архитектур из обработки изображений к решению задачи построения дикторских моделей является непростой задачей. Возьмём за основу готовое решение, предложенной в рамках [следующей публикации](https://arxiv.org/pdf/2002.06033.pdf) и адаптируем его применительно к выполнению настоящей лабораторной работы.
#
# Необходимо отметить, что построение дикторских моделей, как правило, требует наличия *акустических признаков*, вычисленных для звукозаписей тренировочной, валидационной и тестовой баз данных. В качестве примера подобных признаков в рамках настоящей лабораторной работы воспользуемся *логарифмами энергий на выходе мел-банка фильтров*. Важно отметить, что акустические признаки подвергаются некоторым процедурам предобработки перед их непосредственной передачей в блок построения дикторских моделей. В качестве этих процедур можно выделить: нормализация и масштабирование признаков, сохранение только речевых фреймов на основе разметки детектора речевой активности и т.п.
#
# После того, как акустические признаки подготовлены, они могут быть переданы на блок построения дикторских моделей. Как правило, структура современных дикторских моделей соответствует структуре [x-векторных архитектур](https://www.danielpovey.com/files/2018_icassp_xvectors.pdf). Эти архитектуры состоят из четырёх ключевых элементов:
#
# 1. **Фреймовый уровень.** Предназначен для формирования локальных представлений голоса конкретного человека. На этом уровне как раз и применяются нейросетевые архитектуры на базе свёрточных нейронных сетей, например, ResNet, позволяющих с использованием каскадной схемы из множества фильтров с локальной маской захватить некоторый локальный контекст шаблона голоса человека. Выходом фреймового уровня является набор высокоуровневых представлений (карт-признаков), содержащих локальные особенности голоса человека.
#
# 2. **Уровень статистического пулинга** позволяет сформировать промежуточный вектор-признаков, фиксированной длины, которая является одинаковой для звукозаписи любой длительности. В ходе работы блока статистического пулинга происходит удаление временной размерности, присутствующей в картах-признаков. Это достигается путём выполнения процедуры усреднения карт-признаков вдоль оси времени. Выходом уровня статистического пулинга являются вектор среднего и вектор среднеквадратического отклонения, вычисленные на основе карт-признаков. Эти вектора конкатенируются и передаются для дальнейшей обработки на сегментом уровне.
#
# 3. **Сегментный уровень.** Предназначен для трансформации промежуточного вектора, как правило, высокой размерности, в компактный вектор-признаков, представляющий собой дикторский эмбеддинг. Необходимо отметить, что на сегментном уровне расположены один или несколько полносвязных нейросетевых слоёв, а обработка данных выполняется по отношению ко всей звукозаписи, а не только к некоторому её локальному контексту, как на фреймовом уровне.
#
# 4. **Уровень выходного слоя.** Представляет полносвязный слой с softmax-функциями активации. Количество активаций равно числу дикторов в тренирочной выборке. На вход выходноя слоя подаётся дикторский эмбеддинг, а на выходе – формируется набор апостериорных вероятностей, определяющих принадлежность эмбеддинга к одному из дикторских классов в тренировочной выборке. Необходимо отметить, что, как правило, в современных нейросетевых системах построения дикторских моделей выходной используется только на этапе обучения параметров и на этапе тестирования не используется (на этапе тестирования используются только три первых уровня архитектуры).
#
# Обучение модели генерации дикторских эмбеддингов выполняется путём решения задачи *классификации* или, выражаясь терминами из области биометрии, *идентификации на закрытом множестве* (количество дикторских меток является строго фиксированным). В качестве используемой стоимостной функции выступает *категориальная кросс-энтропия*. Обучение выполняется с помощью мини-батчей, содержащих короткие фрагменты карт акустических признаков (длительностью несколько секунд) различных дикторов из тренировочной базы данных. Обучение на коротких фрагментов позволяет избежать сильного переобучения нейросетевой модели. При выполнении процедуры обучения требуется подобрать набор гиперпараметров, выбрать обучения и метод численной оптимизации.
#
# Для успешного выполнения настоящего пункта необходимо сделать следующее:
#
# 1. Сгенерировать списки тренировочных, валидационных и тестовых данных на основе идентификационного протокола базы VoxCeleb1, содержащегося в файле **../data/voxceleb1_test/iden_split.txt**. При генерации списков требуется исключить из них звукозаписи дикторов, которые входят в базу [VoxCeleb1 test set](https://thor.robots.ox.ac.uk/~vgg/data/voxceleb/vox1a/vox1_test_wav.zip). Это позволит выполнить тестирования обученных блоков генерации дикторских моделей на протоколе [VoxCeleb1-O cleaned](https://www.robots.ox.ac.uk/~vgg/data/voxceleb/meta/veri_test2.txt), который составлен по отношению к данным из VoxCeleb1 test set, в лабораторной работе №4.
#
# 2. Инициализировать обучаемую дикторскую модель, выбрав любой возможный вариант её архитектуры, предлагаемый в рамках лабораторной работы. При реализации блока статистического пулинга предлагается выбрать либо его классический вариант, предложенный в [следующей работе](https://www.danielpovey.com/files/2018_icassp_xvectors.pdf), либо его более продвинутую версию основанную на использовании [механизмов внимания](https://arxiv.org/pdf/1803.10963.pdf). Использование последней версии статистического пулинга позволяет реализовать детектор речевой активности прямо внутри блока построения дикторских моделей.
#
# 3. Инициализировать загрузчики тренировочной и валидационной выборки.
#
# 4. Инициализировать оптимизатор и планировщик для выполнения процедуры обучения.
#
# 5. Описать процедуру валидации/тестирования блока построения дикторских моделей.
#
# 6. Описать процедуру обучения и запустить её, контролируя значения стоимостной функции и доли правильных ответов на тренировочном множестве, а также долю правильных ответов на валидационном множестве.

# %%
# Select hyperparameters

# Acoustic features
n_mels            = 40                                   # number of mel filters in bank filters
log_input         = True                                 # logarithm of features by level

# Neural network archtecture
layers            = [3, 4, 6, 3]                         # number of ResNet blocks in different level of frame level
activation        = nn.ReLU                              # activation function used in ResNet blocks
num_filters       = [32, 64, 128, 256]                   # number of filters of ResNet blocks in different level of frame level
encoder_type      = 'SP'                                 # type of statistic pooling layer ('SP'  – classical statistic pooling 
                                                         # layer and 'ASP' – attentive statistic pooling)
nOut              = 512                                  # embedding size

# Loss function for angular losses
margin            = 0.35                                 # margin parameter
scale             = 32.0                                 # scale parameter

# Train dataloader
max_frames_train  = 200                                  # number of frame to train
train_path        = '../data/voxceleb1_dev/wav'          # path to train wav files
batch_size_train  = 128                                  # batch size to train
pin_memory        = False                                # pin memory
num_workers_train = 5                                    # number of workers to train
shuffle           = True                                 # shuffling of training examples

# Validation dataloader
max_frames_val    = 1000                                 # number of frame to validate
val_path          = '../data/voxceleb1_dev/wav'          # path to val wav files
batch_size_val    = 128                                  # batch size to validate
num_workers_val   = 5                                    # number of workers to validate

# Test dataloader
max_frames_test   = 1000                                 # number of frame to test
test_path         = '../data/voxceleb1_dev/wav'          # path to val wav files
batch_size_test   = 128                                  # batch size to test
num_workers_test  = 5                                    # number of workers to test

# Optimizer
lr                = 2.5                                  # learning rate value
weight_decay      = 0                                    # weight decay value

# Scheduler
val_interval      = 5                                    # frequency of validation step
max_epoch         = 40                                   # number of epoches

# Augmentation
musan_path        = '../data/musan_split'                # path to splitted SLR17 dataset
rir_path          = '../data/RIRS_NOISES/simulated_rirs' # path to SLR28 dataset

# %%
# Generate data lists
train_list = []
val_list   = []
test_list  = []

with open('../data/voxceleb1_test/iden_split.txt', 'r') as f:
    lines = f.readlines()
    
black_list = os.listdir('../data/voxceleb1_test/wav')   # exclude speaker IDs from VoxCeleb1 test set
num_train_spk = []                                      # number of train speakers

for line in lines:
    line   = line.strip().split(' ')
    spk_id = line[1].split('/')[0]
    
    if not (spk_id in black_list):
        num_train_spk.append(spk_id)
        
    else:
        continue
    
    # Train list
    if (line[0] == '1'):
        train_list.append(' '.join([spk_id, line[1]]))
    
    # Validation list
    elif (line[0] == '2'):
        val_list.append(' '.join([spk_id, line[1]]))
    
    # Test list
    elif (line[0] == '3'):
        test_list.append(' '.join([spk_id, line[1]]))
        
num_train_spk = len(set(num_train_spk))

# %%
# Initialize model
model      = ResNet(BasicBlock, layers=layers, activation=activation, num_filters=num_filters, nOut=nOut, encoder_type=encoder_type, n_mels=n_mels, log_input=log_input)
trainfunc  = AAMSoftmaxLoss(nOut=nOut, nClasses=num_train_spk, margin=margin, scale=scale)
main_model = MainModel(model, trainfunc).cuda()
# Out:
# Embedding size is 512, encoder SP.
# Initialised AAM softmax margin 0.350 scale 32.000.

# %%
# Initialize train dataloader (without augmentation)
train_dataset = train_dataset_loader(train_list=train_list, max_frames=max_frames_train, train_path=train_path)
train_loader  = DataLoader(train_dataset, batch_size=batch_size_train, pin_memory=pin_memory, num_workers=num_workers_train, shuffle=shuffle)

# Initialize validation dataloader
val_dataset = test_dataset_loader(test_list=val_list, max_frames=max_frames_val, test_path=val_path)
val_loader  = DataLoader(val_dataset, batch_size=batch_size_val, num_workers=num_workers_val)

# %%
# Initialize optimizer and scheduler
optimizer = SGDOptimizer(main_model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = OneCycleLRScheduler(optimizer, 
                                pct_start=0.30, 
                                cycle_momentum=False, 
                                max_lr=lr, 
                                div_factor=20, 
                                final_div_factor=10000, 
                                total_steps=max_epoch*len(train_loader))
# Out:
# Initialised SGD optimizer.
# Initialised OneCycle LR scheduler.

# %%
start_epoch = 0
checkpoint_flag = True

if checkpoint_flag:
    start_epoch = loadParameters(main_model, optimizer, scheduler, path='../data/lab3_models/lab3_model_0024.pth')
    start_epoch = start_epoch + 1

# Train model
for num_epoch in range(start_epoch, max_epoch):
    train_loss, train_top1 = train_network(train_loader, main_model, optimizer, scheduler, num_epoch, verbose=True)
    
    print("Epoch {:1.0f}, Loss (train set) {:f}, Accuracy (train set) {:2.3f}%".format(num_epoch, train_loss, train_top1))

    if (num_epoch + 1)%val_interval == 0:
        _, val_top1 = test_network(val_loader, main_model)
        
        print("Epoch {:1.0f}, Accuracy (validation set) {:2.3f}%".format(num_epoch, val_top1.item()))
        
        saveParameters(main_model, optimizer, scheduler, num_epoch, path='../data/lab3_models')

# %% [markdown]
# **3. Обучение параметров блока построения дикторских моделей с учётом процедуры аугментации данных**
#
# Известно, что рроцедуры формирования и передачи речевого сигнала могут сопровождаться воздействием шумов и помех, приводящих к искажению сигнала. В качестве примеров искажающих факторов, влияющих на ухудшение качестве речевого сигнала можно привести: импульсный отклик помещения (реверберация), фоновый шум голосов группы нецелевых дикторов, звук телевизора или радиоприёмника и т.п. Разработка конвейера системы голосовой биометрии требует учёта воздействия искажающих факторов на качество её работы. Поскольку процедура построения современных дикторских моделей основана на обучении глубоких нейронных сетей, требующих большие объёмы данных для обучения их параметров, возможным вариантом увеличения тренировочной выборки может являться использование методов аугментации статистических данных. *Аугментация* – методика создания дополнительных обучающих примеров из имеющихся данных путём внесения в них искажений, которые могут потенциально возникнуть на этапе итогового тестирования системы.
#
# Как правило, при решении задачи аугментации данных в речевой обработке используются дополнительные базы шумов и помех. В качестве примеров можно привести базы [SLR17](https://openslr.org/17/) (корпус музыкальных, речевых и шумовых звукозаписей) и [SLR28](https://openslr.org/28/) (база данных реальных и симулированных импульсных откликов комнат, а также изотропных и точечных шумов). Важно отметить, что перед применением с использованием методов аугментации подобных баз к имеющимся данным, требуется убедиться, что частоты дискретизации искажающих баз и оригинальных данных являются одинаковыми. Применительно к рассматриваемому лабораторному практикуму частоты дискретизации всех используемых звукозаписей должны быть равными 16кГц.
#
# Как известно, можно выделить два режима аугментации данных: *онлайн* (применяется в ходе процедуры обучения) и *оффлайн* (применяется до процедуры обучения) аугментацию. В рамках настоящей лабораторной работы предлагается использовать онлайн аугментацию в силу не очень большого набора тренировочных данных и большей гибкости экспериментов, чем вс случае онлайн аугментации. Необходимо отметить, что применение онлайн аугментации на практике замедляет процедуру обучения, по сравнению с оффлайн аугментацией, так как наложение искажений, извлечение акустических признаков и их возможная предобработка требует определённого машинного времени.
#
# В рамках настоящего пункта предлагается сделать следующее:
#
# 1. Загрузить и извлечь данные из базы SLR17 (MUSAN). Частота дискретизации данных в рассматриваемой базе равна 16кГц по умолчанию. Поскольку звукозаписи рассматриваемой базы являются достаточно длинными, рекомендуется предварительно разбить эту базу на более маленькие фрагменты (например, длительностью 5 секунд с шагом 3 секунды), сохранив их на диск.
#
# 2. Загрузить и извлечь данные из базы SLR28 (MUSAN). Частота дискретизации данных в рассматриваемой базе равна 16кГц по умолчанию.
#
# 3. Модернизировать загрузчик тренировочных данных под возможность случайного наложения (искажаем исходные звукозаписи) и не наложения (не искажаем исходные звукозаписи) одного из четырёх типов искажений (реверберация, музыкальный шум, фоновый шум голосов нескольких дикторов, неструктурированный шум), описанных внутри класса **AugmentWAV** следующего программного кода: **../common/DatasetLoader.py**.
#
# 4. Используя процедуру обучения из предыдущего пункта с идентичными настройками выполнить тренировку параметров блока генерации дикторских моделей на исходных данных при наличии их аугментирвоанных копий.

# %%
# Download SLR17 (MUSAN) and SLR28 (RIR noises) datasets
with open('../data/lists/augment_datasets.txt', 'r') as f:
    lines = f.readlines()
    
download_dataset(lines, user=None, password=None, save_path='../data')

# %%
# Extract SLR17 (MUSAN)
extract_dataset(save_path='../data', fname='../data/musan.tar.gz')

# Extract SLR28 (RIR noises)
part_extract(save_path='../data', fname='../data/rirs_noises.zip', target=['RIRS_NOISES/simulated_rirs/mediumroom', 'RIRS_NOISES/simulated_rirs/smallroom'])

# %%
# Split MUSAN (SLR17) dataset for faster random access
split_musan(save_path='../data')

# %%
# Initialize model
model      = ResNet(BasicBlock, layers=layers, activation=activation, num_filters=num_filters, nOut=nOut, encoder_type=encoder_type, n_mels=n_mels, log_input=log_input)
trainfunc  = AAMSoftmaxLoss(nOut=nOut, nClasses=num_train_spk, margin=margin, scale=scale)
main_model = MainModel(model, trainfunc).cuda()
# Out:
# Embedding size is 512, encoder SP.
# Initialised AAM softmax margin 0.350 scale 32.000.

# %%
# Initialize train dataloader (without augmentation)
train_dataset = train_dataset_loader(train_list=train_list, 
                                     max_frames=max_frames_train, 
                                     train_path=train_path, 
                                     augment=True, 
                                     musan_path=musan_path, 
                                     rir_path=rir_path)

train_loader  = DataLoader(train_dataset, batch_size=batch_size_train, pin_memory=pin_memory, num_workers=num_workers_train, shuffle=shuffle)

# Initialize validation dataloader
val_dataset = test_dataset_loader(test_list=val_list, max_frames=max_frames_val, test_path=val_path)
val_loader  = DataLoader(val_dataset, batch_size=batch_size_val, num_workers=num_workers_val)

# %%
# Initialize optimizer and scheduler
optimizer = SGDOptimizer(main_model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = OneCycleLRScheduler(optimizer, 
                                pct_start=0.30, 
                                cycle_momentum=False, 
                                max_lr=lr, 
                                div_factor=20, 
                                final_div_factor=10000, 
                                total_steps=max_epoch*len(train_loader))
# Out:
# Initialised SGD optimizer.
# Initialised OneCycle LR scheduler.

# %%
start_epoch = 0
checkpoint_flag = True

if checkpoint_flag:
    start_epoch = loadParameters(main_model, optimizer, scheduler, path='../data/lab3_models_aug/lab3_model_0014.pth')
    start_epoch = start_epoch + 1

# Train model
for num_epoch in range(start_epoch, max_epoch):
    train_loss, train_top1 = train_network(train_loader, main_model, optimizer, scheduler, num_epoch, verbose=True)
    
    print("Epoch {:1.0f}, Loss (train set) {:f}, Accuracy (train set) {:2.3f}%".format(num_epoch, train_loss, train_top1))

    if (num_epoch + 1)%val_interval == 0:
        _, val_top1 = test_network(val_loader, main_model)
        
        print("Epoch {:1.0f}, Accuracy (validation set) {:2.3f}%".format(num_epoch, val_top1.item()))
        
        saveParameters(main_model, optimizer, scheduler, num_epoch, path='../data/lab3_models_aug')
# Out:
# c:\ITMO\sr_labs_book\lab3\exercises_blank.py:207: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# Epoch 15, Batch 1, LR 2.429810 Loss 6.443559, Accuracy 86.719%
# Epoch 15, Batch 2, LR 2.429766 Loss 6.422229, Accuracy 86.328%
# Epoch 15, Batch 3, LR 2.429722 Loss 6.387338, Accuracy 85.938%
# Epoch 15, Batch 4, LR 2.429677 Loss 6.486565, Accuracy 84.180%
# Epoch 15, Batch 5, LR 2.429633 Loss 6.566819, Accuracy 84.219%
# Epoch 15, Batch 6, LR 2.429589 Loss 6.664732, Accuracy 84.115%
# Epoch 15, Batch 7, LR 2.429544 Loss 6.588431, Accuracy 84.598%
# Epoch 15, Batch 8, LR 2.429500 Loss 6.606459, Accuracy 84.863%
# Epoch 15, Batch 9, LR 2.429456 Loss 6.549661, Accuracy 84.896%
# Epoch 15, Batch 10, LR 2.429411 Loss 6.525183, Accuracy 85.469%
# Epoch 15, Batch 11, LR 2.429367 Loss 6.583172, Accuracy 84.872%
# Epoch 15, Batch 12, LR 2.429323 Loss 6.581028, Accuracy 85.156%
# Epoch 15, Batch 13, LR 2.429278 Loss 6.549153, Accuracy 85.337%
# Epoch 15, Batch 14, LR 2.429234 Loss 6.576628, Accuracy 85.100%
# Epoch 15, Batch 15, LR 2.429189 Loss 6.563449, Accuracy 85.052%
# Epoch 15, Batch 16, LR 2.429145 Loss 6.546233, Accuracy 85.107%
# Epoch 15, Batch 17, LR 2.429100 Loss 6.542342, Accuracy 85.202%
# Epoch 15, Batch 18, LR 2.429056 Loss 6.539825, Accuracy 85.200%
# Epoch 15, Batch 19, LR 2.429011 Loss 6.561214, Accuracy 85.074%
# Epoch 15, Batch 20, LR 2.428967 Loss 6.533236, Accuracy 85.234%
# Epoch 15, Batch 21, LR 2.428922 Loss 6.568355, Accuracy 84.933%
# Epoch 15, Batch 22, LR 2.428878 Loss 6.573743, Accuracy 84.943%
# Epoch 15, Batch 23, LR 2.428833 Loss 6.548521, Accuracy 85.020%
# Epoch 15, Batch 24, LR 2.428789 Loss 6.558916, Accuracy 84.863%
# Epoch 15, Batch 25, LR 2.428744 Loss 6.539414, Accuracy 85.031%
# Epoch 15, Batch 26, LR 2.428700 Loss 6.537797, Accuracy 85.096%
# Epoch 15, Batch 27, LR 2.428655 Loss 6.548379, Accuracy 85.127%
# Epoch 15, Batch 28, LR 2.428610 Loss 6.547612, Accuracy 85.184%
# Epoch 15, Batch 29, LR 2.428566 Loss 6.567293, Accuracy 85.156%
# Epoch 15, Batch 30, LR 2.428521 Loss 6.568256, Accuracy 85.026%
# Epoch 15, Batch 31, LR 2.428477 Loss 6.541128, Accuracy 85.232%
# Epoch 15, Batch 32, LR 2.428432 Loss 6.541435, Accuracy 85.229%
# Epoch 15, Batch 33, LR 2.428387 Loss 6.513167, Accuracy 85.346%
# Epoch 15, Batch 34, LR 2.428342 Loss 6.533250, Accuracy 85.248%
# Epoch 15, Batch 35, LR 2.428298 Loss 6.547321, Accuracy 85.156%
# Epoch 15, Batch 36, LR 2.428253 Loss 6.544402, Accuracy 85.200%
# Epoch 15, Batch 37, LR 2.428208 Loss 6.540978, Accuracy 85.177%
# Epoch 15, Batch 38, LR 2.428164 Loss 6.534721, Accuracy 85.259%
# Epoch 15, Batch 39, LR 2.428119 Loss 6.542266, Accuracy 85.176%
# Epoch 15, Batch 40, LR 2.428074 Loss 6.545019, Accuracy 85.215%
# Epoch 15, Batch 41, LR 2.428029 Loss 6.540037, Accuracy 85.232%
# Epoch 15, Batch 42, LR 2.427984 Loss 6.530107, Accuracy 85.342%
# Epoch 15, Batch 43, LR 2.427940 Loss 6.519953, Accuracy 85.411%
# Epoch 15, Batch 44, LR 2.427895 Loss 6.515049, Accuracy 85.369%
# Epoch 15, Batch 45, LR 2.427850 Loss 6.517207, Accuracy 85.347%
# Epoch 15, Batch 46, LR 2.427805 Loss 6.516340, Accuracy 85.445%
# Epoch 15, Batch 47, LR 2.427760 Loss 6.510336, Accuracy 85.522%
# Epoch 15, Batch 48, LR 2.427715 Loss 6.513799, Accuracy 85.563%
# Epoch 15, Batch 49, LR 2.427670 Loss 6.507787, Accuracy 85.507%
# Epoch 15, Batch 50, LR 2.427625 Loss 6.501615, Accuracy 85.484%
# Epoch 15, Batch 51, LR 2.427581 Loss 6.496511, Accuracy 85.463%
# Epoch 15, Batch 52, LR 2.427536 Loss 6.506937, Accuracy 85.412%
# Epoch 15, Batch 53, LR 2.427491 Loss 6.512702, Accuracy 85.333%
# Epoch 15, Batch 54, LR 2.427446 Loss 6.512265, Accuracy 85.359%
# Epoch 15, Batch 55, LR 2.427401 Loss 6.507440, Accuracy 85.256%
# Epoch 15, Batch 56, LR 2.427356 Loss 6.501240, Accuracy 85.310%
# Epoch 15, Batch 57, LR 2.427311 Loss 6.494760, Accuracy 85.307%
# Epoch 15, Batch 58, LR 2.427266 Loss 6.501492, Accuracy 85.291%
# Epoch 15, Batch 59, LR 2.427221 Loss 6.490216, Accuracy 85.408%
# Epoch 15, Batch 60, LR 2.427176 Loss 6.489397, Accuracy 85.430%
# Epoch 15, Batch 61, LR 2.427131 Loss 6.490936, Accuracy 85.387%
# Epoch 15, Batch 62, LR 2.427085 Loss 6.493770, Accuracy 85.345%
# Epoch 15, Batch 63, LR 2.427040 Loss 6.495461, Accuracy 85.317%
# Epoch 15, Batch 64, LR 2.426995 Loss 6.494228, Accuracy 85.254%
# Epoch 15, Batch 65, LR 2.426950 Loss 6.494309, Accuracy 85.300%
# Epoch 15, Batch 66, LR 2.426905 Loss 6.499034, Accuracy 85.263%
# Epoch 15, Batch 67, LR 2.426860 Loss 6.501932, Accuracy 85.250%
# Epoch 15, Batch 104, LR 2.425180 Loss 6.508068, Accuracy 85.141%
# Epoch 15, Batch 105, LR 2.425135 Loss 6.507377, Accuracy 85.164%
# Epoch 15, Batch 106, LR 2.425089 Loss 6.508624, Accuracy 85.142%
# Epoch 15, Batch 107, LR 2.425043 Loss 6.503664, Accuracy 85.178%
# Epoch 15, Batch 108, LR 2.424997 Loss 6.498702, Accuracy 85.200%
# Epoch 15, Batch 109, LR 2.424952 Loss 6.501067, Accuracy 85.214%
# Epoch 15, Batch 110, LR 2.424906 Loss 6.505975, Accuracy 85.185%
# Epoch 15, Batch 111, LR 2.424860 Loss 6.508899, Accuracy 85.156%
# Epoch 15, Batch 112, LR 2.424815 Loss 6.515183, Accuracy 85.121%
# Epoch 15, Batch 113, LR 2.424769 Loss 6.515600, Accuracy 85.115%
# Epoch 15, Batch 114, LR 2.424723 Loss 6.515756, Accuracy 85.060%
# Epoch 15, Batch 115, LR 2.424677 Loss 6.524479, Accuracy 85.020%
# Epoch 15, Batch 116, LR 2.424631 Loss 6.523795, Accuracy 85.028%
# Epoch 15, Batch 117, LR 2.424586 Loss 6.526743, Accuracy 85.043%
# Epoch 15, Batch 118, LR 2.424540 Loss 6.534496, Accuracy 85.004%
# Epoch 15, Batch 119, LR 2.424494 Loss 6.534675, Accuracy 85.025%
# Epoch 15, Batch 120, LR 2.424448 Loss 6.533165, Accuracy 85.052%
# Epoch 15, Batch 121, LR 2.424402 Loss 6.532518, Accuracy 85.072%
# Epoch 15, Batch 122, LR 2.424356 Loss 6.527329, Accuracy 85.105%
# Epoch 15, Batch 123, LR 2.424310 Loss 6.527383, Accuracy 85.124%
# Epoch 15, Batch 124, LR 2.424265 Loss 6.528699, Accuracy 85.106%
# Epoch 15, Batch 125, LR 2.424219 Loss 6.524958, Accuracy 85.094%
# Epoch 15, Batch 126, LR 2.424173 Loss 6.525250, Accuracy 85.082%
# Epoch 15, Batch 127, LR 2.424127 Loss 6.525171, Accuracy 85.101%
# Epoch 15, Batch 128, LR 2.424081 Loss 6.527137, Accuracy 85.071%
# Epoch 15, Batch 129, LR 2.424035 Loss 6.530507, Accuracy 85.035%
# Epoch 15, Batch 130, LR 2.423989 Loss 6.534302, Accuracy 85.000%
# Epoch 15, Batch 131, LR 2.423943 Loss 6.527803, Accuracy 85.049%
# Epoch 15, Batch 132, LR 2.423897 Loss 6.530390, Accuracy 85.014%
# Epoch 15, Batch 133, LR 2.423851 Loss 6.534358, Accuracy 84.986%
# Epoch 15, Batch 134, LR 2.423805 Loss 6.539574, Accuracy 84.993%
# Epoch 15, Batch 135, LR 2.423759 Loss 6.536461, Accuracy 85.017%
# Epoch 15, Batch 136, LR 2.423713 Loss 6.532997, Accuracy 85.053%
# Epoch 15, Batch 137, LR 2.423666 Loss 6.531476, Accuracy 85.071%
# Epoch 15, Batch 138, LR 2.423620 Loss 6.532299, Accuracy 85.066%
# Epoch 15, Batch 139, LR 2.423574 Loss 6.531791, Accuracy 85.066%
# Epoch 15, Batch 140, LR 2.423528 Loss 6.528561, Accuracy 85.089%
# Epoch 15, Batch 471, LR 2.407523 Loss 6.654998, Accuracy 84.393%
# Epoch 15, Batch 472, LR 2.407472 Loss 6.652797, Accuracy 84.405%
# Epoch 15, Batch 473, LR 2.407422 Loss 6.653131, Accuracy 84.403%
# Epoch 15, Batch 474, LR 2.407371 Loss 6.652171, Accuracy 84.411%
# Epoch 15, Batch 475, LR 2.407320 Loss 6.652478, Accuracy 84.410%
# Epoch 15, Batch 476, LR 2.407270 Loss 6.652905, Accuracy 84.408%
# Epoch 15, Batch 477, LR 2.407219 Loss 6.653025, Accuracy 84.409%
# Epoch 15, Batch 478, LR 2.407169 Loss 6.654425, Accuracy 84.401%
# Epoch 15, Batch 479, LR 2.407118 Loss 6.654757, Accuracy 84.399%
# Epoch 15, Batch 480, LR 2.407067 Loss 6.654152, Accuracy 84.404%
# Epoch 15, Batch 481, LR 2.407017 Loss 6.653505, Accuracy 84.409%
# Epoch 15, Batch 482, LR 2.406966 Loss 6.653269, Accuracy 84.414%
# Epoch 15, Batch 483, LR 2.406915 Loss 6.654236, Accuracy 84.407%
# Epoch 15, Batch 484, LR 2.406864 Loss 6.653324, Accuracy 84.412%
# Epoch 15, Batch 485, LR 2.406814 Loss 6.654741, Accuracy 84.417%
# Epoch 15, Batch 486, LR 2.406763 Loss 6.654617, Accuracy 84.418%
# Epoch 15, Batch 487, LR 2.406712 Loss 6.652768, Accuracy 84.433%
# Epoch 15, Batch 488, LR 2.406661 Loss 6.653361, Accuracy 84.423%
# Epoch 15, Batch 489, LR 2.406611 Loss 6.653501, Accuracy 84.426%
# Epoch 15, Batch 490, LR 2.406560 Loss 6.653341, Accuracy 84.431%
# Epoch 15, Batch 491, LR 2.406509 Loss 6.652178, Accuracy 84.435%
# Epoch 15, Batch 492, LR 2.406458 Loss 6.653495, Accuracy 84.426%
# Epoch 15, Batch 493, LR 2.406407 Loss 6.653368, Accuracy 84.426%
# Epoch 15, Batch 494, LR 2.406356 Loss 6.653760, Accuracy 84.422%
# Epoch 15, Batch 495, LR 2.406305 Loss 6.654168, Accuracy 84.416%
# Epoch 15, Batch 496, LR 2.406255 Loss 6.654869, Accuracy 84.413%
# Epoch 15, Batch 497, LR 2.406204 Loss 6.655531, Accuracy 84.408%
# Epoch 15, Batch 498, LR 2.406153 Loss 6.655591, Accuracy 84.406%
# Epoch 15, Batch 499, LR 2.406102 Loss 6.656422, Accuracy 84.400%
# Epoch 15, Batch 500, LR 2.406051 Loss 6.656374, Accuracy 84.394%
# Epoch 15, Batch 501, LR 2.406000 Loss 6.657098, Accuracy 84.391%
# Epoch 15, Batch 502, LR 2.405949 Loss 6.657164, Accuracy 84.383%
# Epoch 15, Batch 503, LR 2.405898 Loss 6.656515, Accuracy 84.384%
# Epoch 15, Batch 504, LR 2.405847 Loss 6.655761, Accuracy 84.381%
# Epoch 15, Batch 505, LR 2.405796 Loss 6.655733, Accuracy 84.373%
# Epoch 15, Batch 506, LR 2.405745 Loss 6.657704, Accuracy 84.360%
# Epoch 15, Batch 507, LR 2.405694 Loss 6.657658, Accuracy 84.353%
# Epoch 15, Batch 508, LR 2.405643 Loss 6.657590, Accuracy 84.350%
# Epoch 15, Batch 509, LR 2.405592 Loss 6.658452, Accuracy 84.343%
# Epoch 15, Batch 510, LR 2.405541 Loss 6.657999, Accuracy 84.338%
# Epoch 15, Batch 511, LR 2.405490 Loss 6.657660, Accuracy 84.335%
# Epoch 15, Batch 512, LR 2.405439 Loss 6.658068, Accuracy 84.334%
# Epoch 15, Batch 513, LR 2.405387 Loss 6.658398, Accuracy 84.334%
# Epoch 15, Batch 514, LR 2.405336 Loss 6.658964, Accuracy 84.332%
# Epoch 15, Batch 515, LR 2.405285 Loss 6.659757, Accuracy 84.329%
# Epoch 15, Batch 516, LR 2.405234 Loss 6.661114, Accuracy 84.330%
# Epoch 15, Batch 517, LR 2.405183 Loss 6.661128, Accuracy 84.322%
# Epoch 15, Batch 518, LR 2.405132 Loss 6.661268, Accuracy 84.318%
# Epoch 15, Batch 519, LR 2.405080 Loss 6.661207, Accuracy 84.319%
# Epoch 15, Batch 520, LR 2.405029 Loss 6.659928, Accuracy 84.330%
# Epoch 15, Batch 521, LR 2.404978 Loss 6.659306, Accuracy 84.333%
# Epoch 15, Batch 522, LR 2.404927 Loss 6.658539, Accuracy 84.344%
# Epoch 15, Batch 523, LR 2.404876 Loss 6.658210, Accuracy 84.342%
# Epoch 15, Batch 524, LR 2.404824 Loss 6.658314, Accuracy 84.339%
# Epoch 15, Batch 525, LR 2.404773 Loss 6.658776, Accuracy 84.335%
# Epoch 15, Batch 526, LR 2.404722 Loss 6.659476, Accuracy 84.330%
# Epoch 15, Batch 527, LR 2.404670 Loss 6.659640, Accuracy 84.329%
# Epoch 15, Batch 528, LR 2.404619 Loss 6.659631, Accuracy 84.328%
# Epoch 15, Batch 529, LR 2.404568 Loss 6.659967, Accuracy 84.323%
# Epoch 15, Batch 530, LR 2.404516 Loss 6.659822, Accuracy 84.323%
# Epoch 15, Batch 531, LR 2.404465 Loss 6.661150, Accuracy 84.321%
# Epoch 15, Batch 532, LR 2.404414 Loss 6.660222, Accuracy 84.325%
# Epoch 15, Batch 533, LR 2.404362 Loss 6.662046, Accuracy 84.308%
# Epoch 15, Batch 534, LR 2.404311 Loss 6.662846, Accuracy 84.308%
# Epoch 15, Batch 535, LR 2.404260 Loss 6.662727, Accuracy 84.317%
# Epoch 15, Batch 536, LR 2.404208 Loss 6.662402, Accuracy 84.314%
# Epoch 15, Batch 537, LR 2.404157 Loss 6.661660, Accuracy 84.323%
# Epoch 15, Batch 538, LR 2.404105 Loss 6.662273, Accuracy 84.321%
# Epoch 15, Batch 539, LR 2.404054 Loss 6.663057, Accuracy 84.314%
# Epoch 15, Batch 540, LR 2.404002 Loss 6.661958, Accuracy 84.317%
# Epoch 15, Batch 541, LR 2.403951 Loss 6.661494, Accuracy 84.317%
# Epoch 15, Batch 542, LR 2.403899 Loss 6.660903, Accuracy 84.319%
# Epoch 15, Batch 543, LR 2.403848 Loss 6.661294, Accuracy 84.306%
# Epoch 15, Batch 544, LR 2.403796 Loss 6.663220, Accuracy 84.287%
# Epoch 15, Batch 545, LR 2.403745 Loss 6.663623, Accuracy 84.285%
# Epoch 15, Batch 546, LR 2.403693 Loss 6.663540, Accuracy 84.273%
# Epoch 15, Batch 547, LR 2.403642 Loss 6.662962, Accuracy 84.276%
# Epoch 15, Batch 548, LR 2.403590 Loss 6.661770, Accuracy 84.288%
# Epoch 15, Batch 549, LR 2.403538 Loss 6.661043, Accuracy 84.288%
# Epoch 15, Batch 550, LR 2.403487 Loss 6.661377, Accuracy 84.288%
# Epoch 15, Batch 551, LR 2.403435 Loss 6.660485, Accuracy 84.291%
# Epoch 15, Batch 552, LR 2.403384 Loss 6.659222, Accuracy 84.300%
# Epoch 15, Batch 553, LR 2.403332 Loss 6.660195, Accuracy 84.292%
# Epoch 15, Batch 554, LR 2.403280 Loss 6.660720, Accuracy 84.289%
# Epoch 15, Batch 555, LR 2.403229 Loss 6.661294, Accuracy 84.291%
# Epoch 15, Batch 556, LR 2.403177 Loss 6.661340, Accuracy 84.289%
# Epoch 15, Batch 557, LR 2.403125 Loss 6.661419, Accuracy 84.287%
# Epoch 15, Batch 558, LR 2.403073 Loss 6.662168, Accuracy 84.290%
# Epoch 15, Batch 559, LR 2.403022 Loss 6.661110, Accuracy 84.291%
# Epoch 15, Batch 560, LR 2.402970 Loss 6.660891, Accuracy 84.290%
# Epoch 15, Batch 561, LR 2.402918 Loss 6.662052, Accuracy 84.282%
# Epoch 15, Batch 562, LR 2.402866 Loss 6.662523, Accuracy 84.279%
# Epoch 15, Batch 563, LR 2.402815 Loss 6.662857, Accuracy 84.271%
# Epoch 15, Batch 564, LR 2.402763 Loss 6.661756, Accuracy 84.271%
# Epoch 15, Batch 565, LR 2.402711 Loss 6.660103, Accuracy 84.278%
# Epoch 15, Batch 566, LR 2.402659 Loss 6.659416, Accuracy 84.284%
# Epoch 15, Batch 567, LR 2.402607 Loss 6.659574, Accuracy 84.283%
# Epoch 15, Batch 568, LR 2.402556 Loss 6.659305, Accuracy 84.288%
# Epoch 15, Batch 569, LR 2.402504 Loss 6.659820, Accuracy 84.283%
# Epoch 15, Batch 570, LR 2.402452 Loss 6.658340, Accuracy 84.285%
# Epoch 15, Batch 571, LR 2.402400 Loss 6.658042, Accuracy 84.281%
# Epoch 15, Batch 572, LR 2.402348 Loss 6.658386, Accuracy 84.283%
# Epoch 15, Batch 573, LR 2.402296 Loss 6.657452, Accuracy 84.295%
# Epoch 15, Batch 574, LR 2.402244 Loss 6.657175, Accuracy 84.288%
# Epoch 15, Batch 575, LR 2.402192 Loss 6.657065, Accuracy 84.292%
# Epoch 15, Batch 576, LR 2.402140 Loss 6.657007, Accuracy 84.290%
# Epoch 15, Batch 577, LR 2.402088 Loss 6.657365, Accuracy 84.290%
# Epoch 15, Batch 578, LR 2.402036 Loss 6.658476, Accuracy 84.283%
# Epoch 15, Batch 579, LR 2.401984 Loss 6.659701, Accuracy 84.267%
# Epoch 15, Batch 580, LR 2.401932 Loss 6.660622, Accuracy 84.263%
# Epoch 15, Batch 581, LR 2.401880 Loss 6.659792, Accuracy 84.270%
# Epoch 15, Batch 582, LR 2.401828 Loss 6.659452, Accuracy 84.274%
# Epoch 15, Batch 583, LR 2.401776 Loss 6.660565, Accuracy 84.269%
# Epoch 15, Batch 584, LR 2.401724 Loss 6.660052, Accuracy 84.272%
# Epoch 15, Batch 585, LR 2.401672 Loss 6.658916, Accuracy 84.278%
# Epoch 15, Batch 586, LR 2.401620 Loss 6.659552, Accuracy 84.272%
# Epoch 15, Batch 587, LR 2.401568 Loss 6.658594, Accuracy 84.284%
# Epoch 15, Batch 588, LR 2.401516 Loss 6.657594, Accuracy 84.293%
# Epoch 15, Batch 589, LR 2.401464 Loss 6.657449, Accuracy 84.293%
# Epoch 15, Batch 590, LR 2.401412 Loss 6.656790, Accuracy 84.294%
# Epoch 15, Batch 591, LR 2.401360 Loss 6.656675, Accuracy 84.298%
# Epoch 15, Batch 592, LR 2.401307 Loss 6.655663, Accuracy 84.301%
# Epoch 15, Batch 593, LR 2.401255 Loss 6.655727, Accuracy 84.297%
# Epoch 15, Batch 594, LR 2.401203 Loss 6.655263, Accuracy 84.299%
# Epoch 15, Batch 595, LR 2.401151 Loss 6.655570, Accuracy 84.299%
# Epoch 15, Batch 596, LR 2.401099 Loss 6.655724, Accuracy 84.299%
# Epoch 15, Batch 597, LR 2.401046 Loss 6.656259, Accuracy 84.295%
# Epoch 15, Batch 598, LR 2.400994 Loss 6.656690, Accuracy 84.295%
# Epoch 15, Batch 599, LR 2.400942 Loss 6.656427, Accuracy 84.295%
# Epoch 15, Batch 600, LR 2.400890 Loss 6.656466, Accuracy 84.296%
# Epoch 15, Batch 601, LR 2.400837 Loss 6.655939, Accuracy 84.302%
# Epoch 15, Batch 602, LR 2.400785 Loss 6.656587, Accuracy 84.298%
# Epoch 15, Batch 603, LR 2.400733 Loss 6.655077, Accuracy 84.304%
# Epoch 15, Batch 604, LR 2.400680 Loss 6.655047, Accuracy 84.301%
# Epoch 15, Batch 605, LR 2.400628 Loss 6.655291, Accuracy 84.296%
# Epoch 15, Batch 606, LR 2.400576 Loss 6.653598, Accuracy 84.304%
# Epoch 15, Batch 607, LR 2.400523 Loss 6.654074, Accuracy 84.304%
# Epoch 15, Batch 608, LR 2.400471 Loss 6.653760, Accuracy 84.308%
# Epoch 15, Batch 609, LR 2.400419 Loss 6.654971, Accuracy 84.299%
# Epoch 15, Batch 610, LR 2.400366 Loss 6.654821, Accuracy 84.302%
# Epoch 15, Batch 611, LR 2.400314 Loss 6.655028, Accuracy 84.307%
# Epoch 15, Batch 612, LR 2.400261 Loss 6.654168, Accuracy 84.314%
# Epoch 15, Batch 613, LR 2.400209 Loss 6.653645, Accuracy 84.310%
# Epoch 15, Batch 614, LR 2.400156 Loss 6.653416, Accuracy 84.310%
# Epoch 15, Batch 615, LR 2.400104 Loss 6.653962, Accuracy 84.308%
# Epoch 15, Batch 616, LR 2.400052 Loss 6.654616, Accuracy 84.301%
# Epoch 15, Batch 617, LR 2.399999 Loss 6.654136, Accuracy 84.304%
# Epoch 15, Batch 618, LR 2.399947 Loss 6.654245, Accuracy 84.298%
# Epoch 15, Batch 619, LR 2.399894 Loss 6.654090, Accuracy 84.297%
# Epoch 15, Batch 620, LR 2.399841 Loss 6.653286, Accuracy 84.299%
# Epoch 15, Batch 621, LR 2.399789 Loss 6.654190, Accuracy 84.292%
# Epoch 15, Batch 622, LR 2.399736 Loss 6.652571, Accuracy 84.302%
# Epoch 15, Batch 623, LR 2.399684 Loss 6.652092, Accuracy 84.302%
# Epoch 15, Batch 624, LR 2.399631 Loss 6.652527, Accuracy 84.296%
# Epoch 15, Batch 625, LR 2.399579 Loss 6.652218, Accuracy 84.304%
# Epoch 15, Batch 626, LR 2.399526 Loss 6.652458, Accuracy 84.309%
# Epoch 15, Batch 627, LR 2.399473 Loss 6.652201, Accuracy 84.308%
# Epoch 15, Batch 628, LR 2.399421 Loss 6.652448, Accuracy 84.305%
# Epoch 15, Batch 629, LR 2.399368 Loss 6.651787, Accuracy 84.309%
# Epoch 15, Batch 630, LR 2.399315 Loss 6.651284, Accuracy 84.313%
# Epoch 15, Batch 631, LR 2.399263 Loss 6.651330, Accuracy 84.309%
# Epoch 15, Batch 632, LR 2.399210 Loss 6.652695, Accuracy 84.302%
# Epoch 15, Batch 633, LR 2.399157 Loss 6.652728, Accuracy 84.305%
# Epoch 15, Batch 634, LR 2.399105 Loss 6.652567, Accuracy 84.307%
# Epoch 15, Batch 635, LR 2.399052 Loss 6.653273, Accuracy 84.306%
# Epoch 15, Batch 636, LR 2.398999 Loss 6.653383, Accuracy 84.306%
# Epoch 15, Batch 637, LR 2.398946 Loss 6.652094, Accuracy 84.312%
# Epoch 15, Batch 638, LR 2.398894 Loss 6.652107, Accuracy 84.320%
# Epoch 15, Batch 639, LR 2.398841 Loss 6.651907, Accuracy 84.326%
# Epoch 15, Batch 640, LR 2.398788 Loss 6.652367, Accuracy 84.321%
# Epoch 15, Batch 641, LR 2.398735 Loss 6.652247, Accuracy 84.321%
# Epoch 15, Batch 642, LR 2.398682 Loss 6.652716, Accuracy 84.321%
# Epoch 15, Batch 643, LR 2.398630 Loss 6.652789, Accuracy 84.317%
# Epoch 15, Batch 644, LR 2.398577 Loss 6.652998, Accuracy 84.319%
# Epoch 15, Batch 645, LR 2.398524 Loss 6.653891, Accuracy 84.314%
# Epoch 15, Batch 646, LR 2.398471 Loss 6.653574, Accuracy 84.313%
# Epoch 15, Batch 647, LR 2.398418 Loss 6.653444, Accuracy 84.312%
# Epoch 15, Batch 648, LR 2.398365 Loss 6.653838, Accuracy 84.310%
# Epoch 15, Batch 649, LR 2.398312 Loss 6.653595, Accuracy 84.315%
# Epoch 15, Batch 650, LR 2.398259 Loss 6.653111, Accuracy 84.322%
# Epoch 15, Batch 651, LR 2.398206 Loss 6.653504, Accuracy 84.313%
# Epoch 15, Batch 652, LR 2.398153 Loss 6.652520, Accuracy 84.317%
# Epoch 15, Batch 653, LR 2.398101 Loss 6.651589, Accuracy 84.321%
# Epoch 15, Batch 727, LR 2.394144 Loss 6.651009, Accuracy 84.285%
# Epoch 15, Batch 728, LR 2.394090 Loss 6.651849, Accuracy 84.278%
# Epoch 15, Batch 729, LR 2.394036 Loss 6.652176, Accuracy 84.273%
# Epoch 15, Batch 730, LR 2.393982 Loss 6.651446, Accuracy 84.273%
# Epoch 15, Batch 731, LR 2.393928 Loss 6.650851, Accuracy 84.275%
# Epoch 15, Batch 732, LR 2.393874 Loss 6.650326, Accuracy 84.277%
# Epoch 15, Batch 733, LR 2.393820 Loss 6.649789, Accuracy 84.279%
# Epoch 15, Batch 734, LR 2.393766 Loss 6.650427, Accuracy 84.279%
# Epoch 15, Batch 735, LR 2.393712 Loss 6.650597, Accuracy 84.281%
# Epoch 15, Batch 736, LR 2.393658 Loss 6.650641, Accuracy 84.281%
# ...
# Epoch 39, Batch 805, LR 0.000433 Loss 4.258568, Accuracy 92.502%
# Epoch 39, Batch 806, LR 0.000429 Loss 4.258422, Accuracy 92.503%
# Epoch 39, Batch 807, LR 0.000426 Loss 4.259267, Accuracy 92.495%
# Epoch 39, Batch 808, LR 0.000422 Loss 4.259530, Accuracy 92.495%
# Epoch 39, Batch 809, LR 0.000419 Loss 4.259813, Accuracy 92.494%
# Epoch 39, Batch 810, LR 0.000416 Loss 4.260237, Accuracy 92.491%
# Epoch 39, Batch 811, LR 0.000412 Loss 4.260566, Accuracy 92.493%
# Epoch 39, Batch 812, LR 0.000409 Loss 4.260808, Accuracy 92.492%
# Epoch 39, Batch 813, LR 0.000405 Loss 4.261091, Accuracy 92.490%
# Epoch 39, Batch 814, LR 0.000402 Loss 4.261569, Accuracy 92.488%
# Epoch 39, Batch 815, LR 0.000399 Loss 4.261226, Accuracy 92.488%
# Epoch 39, Batch 816, LR 0.000395 Loss 4.261770, Accuracy 92.486%
# Epoch 39, Batch 817, LR 0.000392 Loss 4.262337, Accuracy 92.486%
# Epoch 39, Batch 818, LR 0.000389 Loss 4.262204, Accuracy 92.488%
# Epoch 39, Batch 819, LR 0.000386 Loss 4.262449, Accuracy 92.482%
# Epoch 39, Batch 820, LR 0.000382 Loss 4.263027, Accuracy 92.476%
# Epoch 39, Batch 821, LR 0.000379 Loss 4.263377, Accuracy 92.475%
# Epoch 39, Batch 822, LR 0.000376 Loss 4.263667, Accuracy 92.475%
# Epoch 39, Batch 823, LR 0.000373 Loss 4.262847, Accuracy 92.475%
# Epoch 39, Batch 824, LR 0.000369 Loss 4.262880, Accuracy 92.477%
# Epoch 39, Batch 825, LR 0.000366 Loss 4.264335, Accuracy 92.470%
# Epoch 39, Batch 826, LR 0.000363 Loss 4.264916, Accuracy 92.464%
# Epoch 39, Batch 827, LR 0.000360 Loss 4.265174, Accuracy 92.461%
# Epoch 39, Batch 828, LR 0.000357 Loss 4.265764, Accuracy 92.458%
# Epoch 39, Batch 829, LR 0.000354 Loss 4.265440, Accuracy 92.459%
# Epoch 39, Batch 830, LR 0.000350 Loss 4.265897, Accuracy 92.454%
# Epoch 39, Batch 831, LR 0.000347 Loss 4.266348, Accuracy 92.454%
# Epoch 39, Batch 832, LR 0.000344 Loss 4.265665, Accuracy 92.458%
# Epoch 39, Batch 833, LR 0.000341 Loss 4.266464, Accuracy 92.449%
# Epoch 39, Batch 834, LR 0.000338 Loss 4.266695, Accuracy 92.444%
# Epoch 39, Batch 835, LR 0.000335 Loss 4.266876, Accuracy 92.444%
# Epoch 39, Batch 836, LR 0.000332 Loss 4.267590, Accuracy 92.440%
# Epoch 39, Batch 837, LR 0.000329 Loss 4.267944, Accuracy 92.438%
# Epoch 39, Batch 838, LR 0.000326 Loss 4.268083, Accuracy 92.435%
# Epoch 39, Batch 839, LR 0.000323 Loss 4.267915, Accuracy 92.437%
# Epoch 39, Batch 840, LR 0.000320 Loss 4.268546, Accuracy 92.436%
# Epoch 39, Batch 841, LR 0.000317 Loss 4.268870, Accuracy 92.434%
# Epoch 39, Batch 842, LR 0.000314 Loss 4.268954, Accuracy 92.432%
# Epoch 39, Batch 843, LR 0.000311 Loss 4.269277, Accuracy 92.429%
# Epoch 39, Batch 844, LR 0.000308 Loss 4.268829, Accuracy 92.433%
# Epoch 39, Batch 845, LR 0.000305 Loss 4.269017, Accuracy 92.429%
# Epoch 39, Batch 846, LR 0.000302 Loss 4.268751, Accuracy 92.431%
# Epoch 39, Batch 847, LR 0.000300 Loss 4.269087, Accuracy 92.428%
# Epoch 39, Batch 848, LR 0.000297 Loss 4.269050, Accuracy 92.429%
# Epoch 39, Batch 849, LR 0.000294 Loss 4.268897, Accuracy 92.429%
# Epoch 39, Batch 850, LR 0.000291 Loss 4.268546, Accuracy 92.429%
# Epoch 39, Batch 851, LR 0.000288 Loss 4.268508, Accuracy 92.430%
# Epoch 39, Batch 852, LR 0.000285 Loss 4.268127, Accuracy 92.431%
# Epoch 39, Batch 853, LR 0.000283 Loss 4.268898, Accuracy 92.433%
# Epoch 39, Batch 854, LR 0.000280 Loss 4.269068, Accuracy 92.431%
# Epoch 39, Batch 855, LR 0.000277 Loss 4.268858, Accuracy 92.431%
# Epoch 39, Batch 856, LR 0.000274 Loss 4.268728, Accuracy 92.430%
# Epoch 39, Batch 857, LR 0.000272 Loss 4.268726, Accuracy 92.432%
# Epoch 39, Batch 858, LR 0.000269 Loss 4.269153, Accuracy 92.430%
# Epoch 39, Batch 859, LR 0.000266 Loss 4.269390, Accuracy 92.429%
# Epoch 39, Batch 860, LR 0.000263 Loss 4.269214, Accuracy 92.430%
# Epoch 39, Batch 861, LR 0.000261 Loss 4.268863, Accuracy 92.431%
# Epoch 39, Batch 862, LR 0.000258 Loss 4.268434, Accuracy 92.431%
# Epoch 39, Batch 863, LR 0.000255 Loss 4.268282, Accuracy 92.428%
# Epoch 39, Batch 864, LR 0.000253 Loss 4.269237, Accuracy 92.422%
# Epoch 39, Batch 865, LR 0.000250 Loss 4.269033, Accuracy 92.421%
# Epoch 39, Batch 866, LR 0.000248 Loss 4.269163, Accuracy 92.418%
# Epoch 39, Batch 867, LR 0.000245 Loss 4.269444, Accuracy 92.417%
# Epoch 39, Batch 868, LR 0.000242 Loss 4.270677, Accuracy 92.410%
# Epoch 39, Batch 869, LR 0.000240 Loss 4.270894, Accuracy 92.410%
# Epoch 39, Batch 870, LR 0.000237 Loss 4.270850, Accuracy 92.411%
# Epoch 39, Batch 871, LR 0.000235 Loss 4.270962, Accuracy 92.410%
# Epoch 39, Batch 872, LR 0.000232 Loss 4.271367, Accuracy 92.407%
# Epoch 39, Batch 873, LR 0.000230 Loss 4.271673, Accuracy 92.410%
# Epoch 39, Batch 874, LR 0.000227 Loss 4.271221, Accuracy 92.409%
# Epoch 39, Batch 875, LR 0.000225 Loss 4.271558, Accuracy 92.404%
# Epoch 39, Batch 876, LR 0.000222 Loss 4.271932, Accuracy 92.400%
# Epoch 39, Batch 877, LR 0.000220 Loss 4.272242, Accuracy 92.399%
# Epoch 39, Batch 878, LR 0.000217 Loss 4.272208, Accuracy 92.397%
# Epoch 39, Batch 879, LR 0.000215 Loss 4.271807, Accuracy 92.399%
# Epoch 39, Batch 880, LR 0.000213 Loss 4.271485, Accuracy 92.402%
# Epoch 39, Batch 881, LR 0.000210 Loss 4.271345, Accuracy 92.406%
# Epoch 39, Batch 882, LR 0.000208 Loss 4.271723, Accuracy 92.405%
# Epoch 39, Batch 883, LR 0.000206 Loss 4.271435, Accuracy 92.404%
# Epoch 39, Batch 884, LR 0.000203 Loss 4.271918, Accuracy 92.404%
# Epoch 39, Batch 885, LR 0.000201 Loss 4.272038, Accuracy 92.405%
# Epoch 39, Batch 886, LR 0.000199 Loss 4.271627, Accuracy 92.404%
# Epoch 39, Batch 887, LR 0.000196 Loss 4.271637, Accuracy 92.401%
# Epoch 39, Batch 888, LR 0.000194 Loss 4.270836, Accuracy 92.405%
# Epoch 39, Batch 889, LR 0.000192 Loss 4.271653, Accuracy 92.402%
# Epoch 39, Batch 890, LR 0.000189 Loss 4.271855, Accuracy 92.399%
# Epoch 39, Batch 891, LR 0.000187 Loss 4.272140, Accuracy 92.396%
# Epoch 39, Batch 892, LR 0.000185 Loss 4.272697, Accuracy 92.395%
# Epoch 39, Batch 893, LR 0.000183 Loss 4.272383, Accuracy 92.396%
# Epoch 39, Batch 894, LR 0.000181 Loss 4.272103, Accuracy 92.399%
# Epoch 39, Batch 895, LR 0.000178 Loss 4.272612, Accuracy 92.399%
# Epoch 39, Batch 896, LR 0.000176 Loss 4.273403, Accuracy 92.396%
# Epoch 39, Batch 897, LR 0.000174 Loss 4.274229, Accuracy 92.394%
# Epoch 39, Batch 898, LR 0.000172 Loss 4.274262, Accuracy 92.394%
# Epoch 39, Batch 899, LR 0.000170 Loss 4.274530, Accuracy 92.394%
# Epoch 39, Batch 900, LR 0.000168 Loss 4.275442, Accuracy 92.391%
# Epoch 39, Batch 901, LR 0.000165 Loss 4.275000, Accuracy 92.393%
# Epoch 39, Batch 902, LR 0.000163 Loss 4.275595, Accuracy 92.392%
# Epoch 39, Batch 903, LR 0.000161 Loss 4.275839, Accuracy 92.391%
# Epoch 39, Batch 904, LR 0.000159 Loss 4.275833, Accuracy 92.392%
# Epoch 39, Batch 905, LR 0.000157 Loss 4.275020, Accuracy 92.396%
# Epoch 39, Batch 906, LR 0.000155 Loss 4.274959, Accuracy 92.395%
# Epoch 39, Batch 907, LR 0.000153 Loss 4.274885, Accuracy 92.398%
# Epoch 39, Batch 908, LR 0.000151 Loss 4.275182, Accuracy 92.395%
# Epoch 39, Batch 909, LR 0.000149 Loss 4.275513, Accuracy 92.392%
# Epoch 39, Batch 910, LR 0.000147 Loss 4.275609, Accuracy 92.393%
# Epoch 39, Batch 911, LR 0.000145 Loss 4.275556, Accuracy 92.393%
# Epoch 39, Batch 912, LR 0.000143 Loss 4.274943, Accuracy 92.391%
# Epoch 39, Batch 913, LR 0.000141 Loss 4.275720, Accuracy 92.390%
# Epoch 39, Batch 914, LR 0.000139 Loss 4.275201, Accuracy 92.393%
# Epoch 39, Batch 915, LR 0.000138 Loss 4.274840, Accuracy 92.395%
# Epoch 39, Batch 916, LR 0.000136 Loss 4.274863, Accuracy 92.393%
# Epoch 39, Batch 917, LR 0.000134 Loss 4.274354, Accuracy 92.395%
# Epoch 39, Batch 918, LR 0.000132 Loss 4.274201, Accuracy 92.390%
# Epoch 39, Batch 919, LR 0.000130 Loss 4.274248, Accuracy 92.389%
# Epoch 39, Batch 920, LR 0.000128 Loss 4.273973, Accuracy 92.391%
# Epoch 39, Batch 921, LR 0.000126 Loss 4.273882, Accuracy 92.391%
# Epoch 39, Batch 922, LR 0.000125 Loss 4.274325, Accuracy 92.390%
# Epoch 39, Batch 923, LR 0.000123 Loss 4.273904, Accuracy 92.390%
# Epoch 39, Batch 924, LR 0.000121 Loss 4.274695, Accuracy 92.385%
# Epoch 39, Batch 925, LR 0.000119 Loss 4.274998, Accuracy 92.387%
# Epoch 39, Batch 926, LR 0.000118 Loss 4.274825, Accuracy 92.382%
# Epoch 39, Batch 927, LR 0.000116 Loss 4.274794, Accuracy 92.380%
# Epoch 39, Batch 928, LR 0.000114 Loss 4.275325, Accuracy 92.382%
# Epoch 39, Batch 929, LR 0.000112 Loss 4.276090, Accuracy 92.380%
# Epoch 39, Batch 930, LR 0.000111 Loss 4.276257, Accuracy 92.382%
# Epoch 39, Batch 931, LR 0.000109 Loss 4.276813, Accuracy 92.381%
# Epoch 39, Batch 932, LR 0.000107 Loss 4.278026, Accuracy 92.377%
# Epoch 39, Batch 933, LR 0.000106 Loss 4.278651, Accuracy 92.377%
# Epoch 39, Batch 934, LR 0.000104 Loss 4.278488, Accuracy 92.377%
# Epoch 39, Batch 935, LR 0.000103 Loss 4.278486, Accuracy 92.378%
# Epoch 39, Batch 936, LR 0.000101 Loss 4.278849, Accuracy 92.374%
# Epoch 39, Batch 937, LR 0.000099 Loss 4.279284, Accuracy 92.375%
# Epoch 39, Batch 938, LR 0.000098 Loss 4.279312, Accuracy 92.374%
# Epoch 39, Batch 939, LR 0.000096 Loss 4.279063, Accuracy 92.372%
# Epoch 39, Batch 940, LR 0.000095 Loss 4.279055, Accuracy 92.371%
# Epoch 39, Batch 941, LR 0.000093 Loss 4.280113, Accuracy 92.369%
# Epoch 39, Batch 942, LR 0.000092 Loss 4.280261, Accuracy 92.368%
# Epoch 39, Batch 943, LR 0.000090 Loss 4.279935, Accuracy 92.370%
# Epoch 39, Batch 944, LR 0.000089 Loss 4.280555, Accuracy 92.371%
# Epoch 39, Batch 945, LR 0.000087 Loss 4.279654, Accuracy 92.374%
# Epoch 39, Batch 946, LR 0.000086 Loss 4.279135, Accuracy 92.379%
# Epoch 39, Batch 947, LR 0.000084 Loss 4.279690, Accuracy 92.374%
# Epoch 39, Batch 948, LR 0.000083 Loss 4.279961, Accuracy 92.375%
# Epoch 39, Batch 949, LR 0.000081 Loss 4.280293, Accuracy 92.375%
# Epoch 39, Batch 950, LR 0.000080 Loss 4.280353, Accuracy 92.375%
# Epoch 39, Batch 951, LR 0.000079 Loss 4.279812, Accuracy 92.377%
# Epoch 39, Batch 952, LR 0.000077 Loss 4.280303, Accuracy 92.379%
# Epoch 39, Batch 953, LR 0.000076 Loss 4.280290, Accuracy 92.377%
# Epoch 39, Batch 954, LR 0.000075 Loss 4.280414, Accuracy 92.373%
# Epoch 39, Batch 955, LR 0.000073 Loss 4.280573, Accuracy 92.370%
# Epoch 39, Batch 956, LR 0.000072 Loss 4.280338, Accuracy 92.369%
# Epoch 39, Batch 957, LR 0.000071 Loss 4.280353, Accuracy 92.370%
# Epoch 39, Batch 958, LR 0.000069 Loss 4.279971, Accuracy 92.373%
# Epoch 39, Batch 959, LR 0.000068 Loss 4.279517, Accuracy 92.375%
# Epoch 39, Batch 960, LR 0.000067 Loss 4.278787, Accuracy 92.379%
# Epoch 39, Batch 961, LR 0.000066 Loss 4.278241, Accuracy 92.381%
# Epoch 39, Batch 962, LR 0.000064 Loss 4.278099, Accuracy 92.384%
# Epoch 39, Batch 963, LR 0.000063 Loss 4.277691, Accuracy 92.385%
# Epoch 39, Batch 964, LR 0.000062 Loss 4.278278, Accuracy 92.381%
# Epoch 39, Batch 965, LR 0.000061 Loss 4.278427, Accuracy 92.383%
# Epoch 39, Batch 966, LR 0.000060 Loss 4.278496, Accuracy 92.383%
# Epoch 39, Batch 967, LR 0.000058 Loss 4.278700, Accuracy 92.385%
# Epoch 39, Batch 968, LR 0.000057 Loss 4.279698, Accuracy 92.381%
# Epoch 39, Batch 969, LR 0.000056 Loss 4.280215, Accuracy 92.376%
# Epoch 39, Batch 970, LR 0.000055 Loss 4.280161, Accuracy 92.374%
# Epoch 39, Batch 971, LR 0.000054 Loss 4.280313, Accuracy 92.373%
# Epoch 39, Batch 972, LR 0.000053 Loss 4.279868, Accuracy 92.374%
# Epoch 39, Batch 973, LR 0.000052 Loss 4.279859, Accuracy 92.372%
# Epoch 39, Batch 974, LR 0.000051 Loss 4.280035, Accuracy 92.372%
# Epoch 39, Batch 975, LR 0.000050 Loss 4.280718, Accuracy 92.369%
# Epoch 39, Batch 976, LR 0.000049 Loss 4.280591, Accuracy 92.372%
# Epoch 39, Batch 977, LR 0.000048 Loss 4.280566, Accuracy 92.372%
# Epoch 39, Batch 978, LR 0.000047 Loss 4.281159, Accuracy 92.371%
# Epoch 39, Batch 979, LR 0.000046 Loss 4.280718, Accuracy 92.370%
# Epoch 39, Batch 980, LR 0.000045 Loss 4.280391, Accuracy 92.374%
# Epoch 39, Batch 981, LR 0.000044 Loss 4.280227, Accuracy 92.375%
# Epoch 39, Batch 982, LR 0.000043 Loss 4.279943, Accuracy 92.378%
# Epoch 39, Batch 983, LR 0.000042 Loss 4.279505, Accuracy 92.378%
# Epoch 39, Batch 984, LR 0.000041 Loss 4.279516, Accuracy 92.380%
# Epoch 39, Batch 985, LR 0.000040 Loss 4.279413, Accuracy 92.385%
# Epoch 39, Batch 986, LR 0.000039 Loss 4.279529, Accuracy 92.386%
# Epoch 39, Batch 987, LR 0.000038 Loss 4.279365, Accuracy 92.389%
# Epoch 39, Batch 988, LR 0.000037 Loss 4.279283, Accuracy 92.390%
# Epoch 39, Batch 989, LR 0.000037 Loss 4.279398, Accuracy 92.390%
# Epoch 39, Batch 990, LR 0.000036 Loss 4.278459, Accuracy 92.393%
# Epoch 39, Batch 991, LR 0.000035 Loss 4.278588, Accuracy 92.392%
# Epoch 39, Batch 992, LR 0.000034 Loss 4.279577, Accuracy 92.387%
# Epoch 39, Batch 993, LR 0.000033 Loss 4.279730, Accuracy 92.388%
# Epoch 39, Batch 994, LR 0.000033 Loss 4.279162, Accuracy 92.390%
# Epoch 39, Batch 995, LR 0.000032 Loss 4.279977, Accuracy 92.389%
# Epoch 39, Batch 996, LR 0.000031 Loss 4.279397, Accuracy 92.391%
# Epoch 39, Batch 997, LR 0.000030 Loss 4.279144, Accuracy 92.394%
# Epoch 39, Batch 998, LR 0.000030 Loss 4.278562, Accuracy 92.396%
# Epoch 39, Batch 999, LR 0.000029 Loss 4.278399, Accuracy 92.396%
# Epoch 39, Batch 1000, LR 0.000028 Loss 4.279488, Accuracy 92.392%
# Epoch 39, Batch 1001, LR 0.000028 Loss 4.279669, Accuracy 92.395%
# Epoch 39, Batch 1002, LR 0.000027 Loss 4.279506, Accuracy 92.397%
# Epoch 39, Batch 1003, LR 0.000026 Loss 4.278723, Accuracy 92.401%
# Epoch 39, Batch 1004, LR 0.000026 Loss 4.278267, Accuracy 92.403%
# Epoch 39, Batch 1005, LR 0.000025 Loss 4.278003, Accuracy 92.405%
# Epoch 39, Batch 1006, LR 0.000025 Loss 4.277769, Accuracy 92.404%
# Epoch 39, Batch 1007, LR 0.000024 Loss 4.277816, Accuracy 92.408%
# Epoch 39, Batch 1008, LR 0.000023 Loss 4.277669, Accuracy 92.408%
# Epoch 39, Batch 1009, LR 0.000023 Loss 4.277490, Accuracy 92.407%
# Epoch 39, Batch 1010, LR 0.000022 Loss 4.277651, Accuracy 92.403%
# Epoch 39, Batch 1011, LR 0.000022 Loss 4.277717, Accuracy 92.402%
# Epoch 39, Batch 1012, LR 0.000021 Loss 4.277920, Accuracy 92.404%
# Epoch 39, Batch 1013, LR 0.000021 Loss 4.278055, Accuracy 92.402%
# Epoch 39, Batch 1014, LR 0.000020 Loss 4.278464, Accuracy 92.396%
# Epoch 39, Batch 1015, LR 0.000020 Loss 4.278078, Accuracy 92.399%
# Epoch 39, Batch 1016, LR 0.000019 Loss 4.278119, Accuracy 92.397%
# Epoch 39, Batch 1017, LR 0.000019 Loss 4.278468, Accuracy 92.396%
# Epoch 39, Batch 1018, LR 0.000019 Loss 4.278260, Accuracy 92.395%
# Epoch 39, Batch 1019, LR 0.000018 Loss 4.278217, Accuracy 92.395%
# Epoch 39, Batch 1020, LR 0.000018 Loss 4.278041, Accuracy 92.395%
# Epoch 39, Batch 1021, LR 0.000017 Loss 4.278375, Accuracy 92.397%
# Epoch 39, Batch 1022, LR 0.000017 Loss 4.278179, Accuracy 92.398%
# Epoch 39, Batch 1023, LR 0.000017 Loss 4.278200, Accuracy 92.400%
# Epoch 39, Batch 1024, LR 0.000016 Loss 4.277668, Accuracy 92.403%
# Epoch 39, Batch 1025, LR 0.000016 Loss 4.278137, Accuracy 92.401%
# Epoch 39, Batch 1026, LR 0.000016 Loss 4.278005, Accuracy 92.401%
# Epoch 39, Batch 1027, LR 0.000015 Loss 4.278349, Accuracy 92.400%
# Epoch 39, Batch 1028, LR 0.000015 Loss 4.278315, Accuracy 92.396%
# Epoch 39, Batch 1029, LR 0.000015 Loss 4.278851, Accuracy 92.396%
# Epoch 39, Batch 1030, LR 0.000015 Loss 4.279322, Accuracy 92.395%
# Epoch 39, Batch 1031, LR 0.000014 Loss 4.279473, Accuracy 92.395%
# Epoch 39, Batch 1032, LR 0.000014 Loss 4.279706, Accuracy 92.393%
# Epoch 39, Batch 1033, LR 0.000014 Loss 4.279251, Accuracy 92.392%
# Epoch 39, Batch 1034, LR 0.000014 Loss 4.279228, Accuracy 92.394%
# Epoch 39, Batch 1035, LR 0.000014 Loss 4.279336, Accuracy 92.396%
# Epoch 39, Batch 1036, LR 0.000013 Loss 4.279193, Accuracy 92.397%
# Epoch 39, Batch 1037, LR 0.000013 Loss 4.279293, Accuracy 92.395%
# Epoch 39, Batch 1038, LR 0.000013 Loss 4.279253, Accuracy 92.394%
# Epoch 39, Batch 1039, LR 0.000013 Loss 4.279816, Accuracy 92.394%
# Epoch 39, Batch 1040, LR 0.000013 Loss 4.279855, Accuracy 92.393%
# Epoch 39, Batch 1041, LR 0.000013 Loss 4.279904, Accuracy 92.393%
# Epoch 39, Batch 1042, LR 0.000013 Loss 4.279164, Accuracy 92.397%
# Epoch 39, Batch 1043, LR 0.000013 Loss 4.278596, Accuracy 92.399%
# Epoch 39, Batch 1044, LR 0.000013 Loss 4.278454, Accuracy 92.400%
# Epoch 39, Batch 1045, LR 0.000013 Loss 4.277918, Accuracy 92.401%
# Epoch 39, Batch 1046, LR 0.000013 Loss 4.278052, Accuracy 92.403%
# Epoch 39, Batch 1047, LR 0.000013 Loss 4.277894, Accuracy 92.400%
# Epoch 39, Loss (train set) 4.277894, Accuracy (train set) 92.400%
# Epoch 39, Accuracy (validation set) 96.271%

# %% [markdown]
# **4. Тестирование блока построения дикторских моделей**
#
# Из литературы известно, что применение алгоритмов машинного обучения на практике требует использования трёх наборов данных: *тренировочное множество* (используется для обучения параметров модели), *валидационное множество* (используется для настройки гиперпараметров), *тестовое множество* (используется для итогового тестирования).
#
# В рамках настоящего пункта предлагается выполнить итоговое тестирования блоков генерации дикторских моделей, обученных без аугментации и с аугментацией тренировочных данных, и сравнить полученные результаты. При проведении процедуры тестирования рекомендуется выбрать различное количество фреймов для тестовых звукозаписей, чтобы грубо понять то, как длительность фонограммы влияет на качество распознавания диктора.
#
# В качестве целевой метрики предлагается использовать *долю правильных ответов*, то есть количество верно классифицированных объектов по отношению к общему количеству объектов тестового множества. Как и при проведении процедуры обучения и валидации, рассматриваемая процедура тестирования предполагает решение задачи идентификации диктора на закрытом множестве.

# %%
# Initialize test dataloader
test_dataset = test_dataset_loader(test_list=test_list, max_frames=max_frames_test, test_path=test_path)
test_loader = DataLoader(test_dataset, batch_size=batch_size_test, num_workers=num_workers_test)

# %%
# Load model without augmentation
num_epoch = loadParameters(main_model, optimizer, scheduler, path='../data/lab3_models/lab3_model_0039.pth')

# Test model
_, test_top1 = test_network(test_loader, main_model)

print("Epoch {:1.0f}, Accuracy (test set) {:2.3f}%".format(num_epoch, test_top1.item()))
# Out:
# c:\ITMO\sr_labs_book\lab3\exercises_blank.py:207: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# Epoch 39, Accuracy (test set) 95.950%

# %%
# Load model with augmentation
num_epoch = loadParameters(main_model, optimizer, scheduler, path='../data/lab3_models_aug/lab3_model_0039.pth')

# Test model
_, test_top1 = test_network(test_loader, main_model)

print("Epoch {:1.0f}, Accuracy (test set) {:2.3f}%".format(num_epoch, test_top1.item()))
# Out:
# c:\ITMO\sr_labs_book\lab3\exercises_blank.py:207: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# Epoch 39, Accuracy (test set) 96.918%

# %% [markdown]
# **5. Контрольные вопросы**
#
# 1. Что такое верификация и идентицикация диктора?
#
# 2. Что такое распознавание диктора на закрытом и открытом множестве?
#
# 3. Что такое текстозависимое и текстонезависимое распознавание диктора?
#
# 4. Описать схему обучения блока генерации дикторских моделей на основе нейронных сетей.
#
# 5. Описать основные компоненты, из которых состоит нейросетевой блок генерации дикторских моделей (фреймовый уровень, слой статистического пулинга, сегментный уровень, выходной слой).
#
# 6. Как устроены нейросетевые архитектуры на основе ResNet-блоков?
#
# 7. Что такое полносвязная нейронная сеть прямого распространения?
#
# 8. Как устроена стоимостная функция для обучения нейросетевого блока генерации дикторских моделей?
#
# 9. Что такое аугментация данных?
#
# 10. Что такое дикторский эмбеддинг и на каком уровне блока построения дикторских моделей он генерируется?

# %% [markdown]
# **6. Список литературы**
#
# 1. Bai Z., Zhang X.-L., Chen J. Speaker recognition based on deep learning: an overview // 	arXiv:2012.00931 [eess.AS] ([ссылка](https://arxiv.org/pdf/2012.00931.pdf)).
#
# 2. Hansen J.H.L., Hasan T. Speaker recognition by machines and humans: a tutorial review // IEEE Signal Processing Magazine, 2015. V. 32. № 6. P. 74–99 ([ссылка](https://www.researchgate.net/publication/282940395_Speaker_Recognition_by_Machines_and_Humans_A_tutorial_review)).
